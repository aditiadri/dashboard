# %%
pip install plotly
# Out:
# ...
#    ---------------------------------------- 0.0/17.3 MB ? eta -:--:--
#    ---------------------------------------- 0.1/17.3 MB ? eta -:--:--
#     --------------------------------------- 0.3/17.3 MB 3.4 MB/s eta 0:00:05
#    - -------------------------------------- 0.5/17.3 MB 4.7 MB/s eta 0:00:04
#    - -------------------------------------- 0.5/17.3 MB 4.7 MB/s eta 0:00:04
#    - -------------------------------------- 0.5/17.3 MB 4.7 MB/s eta 0:00:04
#    - -------------------------------------- 0.5/17.3 MB 4.7 MB/s eta 0:00:04
#    - -------------------------------------- 0.5/17.3 MB 4.7 MB/s eta 0:00:04
#    - -------------------------------------- 0.5/17.3 MB 4.7 MB/s eta 0:00:04
#    -- ------------------------------------- 0.9/17.3 MB 2.3 MB/s eta 0:00:08
#    -- ------------------------------------- 1.0/17.3 MB 2.4 MB/s eta 0:00:07
#    -- ------------------------------------- 1.0/17.3 MB 2.4 MB/s eta 0:00:07
# ...

# %%
import pandas as pd 
import numpy as np 
import plotly.graph_objects as go
import plotly.express as px
import streamlit as st
from datetime import datetime

# %%
df_agg
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 df_agg
#
# NameError: name 'df_agg' is not defined

# %%
df_agg['Video publish time']

# %%
df_agg['Video publish time']
# Out:
# 1     2020-05-08
# 2     2020-11-12
# 3     2020-07-16
# 4     2020-08-29
# 5     2020-08-05
#          ...
# 219   2018-11-30
# 220   2019-05-25
# 221   2018-12-18
# 222   2019-05-05
# 223   2017-06-06
# Name: Video publish time, Length: 223, dtype: datetime64[ns]

# %%
df_agg['Average view duration']
# Out:
# 1      0:03:09
# 2      0:05:14
# 3      0:10:21
# 4      0:02:36
# 5      0:04:37
#         ...
# 219    0:03:28
# 220    0:02:06
# 221    0:01:52
# 222    0:03:09
# 223    0:01:04
# Name: Average view duration, Length: 223, dtype: object

# %%
# Out:
# 1     2024-08-11 00:03:09
# 2     2024-08-11 00:05:14
# 3     2024-08-11 00:10:21
# 4     2024-08-11 00:02:36
# 5     2024-08-11 00:04:37
#               ...
# 219   2024-08-11 00:03:28
# 220   2024-08-11 00:02:06
# 221   2024-08-11 00:01:52
# 222   2024-08-11 00:03:09
# 223   2024-08-11 00:01:04
# Name: Average view duration, Length: 223, dtype: datetime64[ns]

# %%
    df_agg = pd.read_csv('Aggregated_Metrics_By_Video.csv').iloc[1:, :]
    df_agg.columns = [
        'Video', 'Video title', 'Video publish time', 'Comments added', 'Shares', 
        'Dislikes', 'Likes', 'Subscribers lost', 'Subscribers gained', 
        'RPM(USD)', 'CPM(USD)', 'Average % viewed', 'Average view duration',
        'Views', 'Watch time (hours)', 'Subscribers', 
        'Your estimated revenue (USD)', 'Impressions', 'Impressions ctr(%)'
    ]

# %%
 

df_agg
# Out:
#            Video                                        Video title  \
# 1    4OZip0cgOho  How I Would Learn Data Science (If I Had to St...
# 2    78LjdAAw0wA                  100K Channel Update + AMA Stream!
# 3    hO_YKK_0Qck  Uber Driver to Machine Learning Engineer in 9 ...
# 4    uXLnbdHMf8w          Why I'm Starting Data Science Over Again.
# 5    Xgg7dIKys9E  Interview with the Director of AI Research @ N...
# ..           ...                                                ...
# 219  FBgs-BSTIJE                    Demystifying Data Science Roles
# 220  Yr5T3T4tq-g  Most Data Science Hopefuls Overlook This Impor...
# 221  j-Z-je6K4Yg                   IT'S NOT TOO LATE TO LEARN CODE!
# 222  5jntoZX-Tc8  NASA Physicist Turned Data Scientist (Tim Bowl...
# 223  5p73cIRYCZg                     ProjectDemoCSC478_UFCFightData
#
#     Video publish time  Comments added  Shares  Dislikes  Likes  \
# 1          May 8, 2020             907    9583       942  46903
# ...

# %%
 df_time['Date']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 df_time['Date']
#
# NameError: name 'df_time' is not defined

# %%
    

    
    df_agg['Video publish time'] = pd.to_datetime(df_agg['Video publish time'], format='%b %d, %Y')
    df_agg['Average view duration'] = pd.to_datetime(df_agg['Average view duration'])
    print(df_agg['Average view duration'])
    
    df_agg['Avg_duration_sec'] = df_agg['Average view duration'].apply(
        lambda x: x.second + x.minute * 60 + x.hour * 3600
    )
    
    df_agg['Engagement_ratio'] = (
        df_agg['Comments added'] + df_agg['Shares'] + df_agg['Dislikes'] + df_agg['Likes']
    ) / df_agg['Views']
    
    df_agg['Views / sub gained'] = df_agg['Views'] / df_agg['Subscribers gained']
    df_agg.sort_values('Video publish time', ascending=False, inplace=True)
    
    df_agg_sub = pd.read_csv('Aggregated_Metrics_By_Country_And_Subscriber_Status.csv')
    df_comments = pd.read_csv('Aggregated_Metrics_By_Video.csv')
    df_time = pd.read_csv('Video_Performance_Over_Time.csv')
    df_time['Date'] = pd.to_datetime(df_time['Date'], format='%d %b %Y', errors='coerce')
# Out:
# C:\Users\91790\AppData\Local\Temp\ipykernel_4436\672641444.py:2: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df_agg['Average view duration'] = pd.to_datetime(df_agg['Average view duration'])
# 1     2024-08-17 00:03:09
# 2     2024-08-17 00:05:14
# 3     2024-08-17 00:10:21
# 4     2024-08-17 00:02:36
# 5     2024-08-17 00:04:37
#               ...
# 219   2024-08-17 00:03:28
# 220   2024-08-17 00:02:06
# 221   2024-08-17 00:01:52
# 222   2024-08-17 00:03:09
# 223   2024-08-17 00:01:04
# Name: Average view duration, Length: 223, dtype: datetime64[ns]

# %%
df_agg
# Out:
#            Video                                        Video title  \
# 111  0jTtHYie3CU  Should You Be Excited About Web 3? (As a Data ...
# 187  2RWwN5ZT4tA  Should  @Luke Barousse Take This Data Analyst ...
# 64   rEWPqw6rMGI         The Only Data Science Explanation You Need
# 59   o-wsyxWbPOw  We Need to Talk About The LinkedIn Machine Lea...
# 32   xpIFS6jZbe8  How I Would Learn Data Science in 2022 (If I H...
# ..           ...                                                ...
# 75   RRSRKf9eQxc          Should You Get A Masters in Data Science?
# 190  IFceyuL6GZY  How I Became A Data Scientist From a Business ...
# 204  Y_SMU701qlA  Predicting Season Long NBA Wins Using Multiple...
# 138  qfRhKHV8-t4  Predicting Crypto-Currency Price Using RNN lST...
# 223  5p73cIRYCZg                     ProjectDemoCSC478_UFCFightData
#
#     Video publish time  Comments added  Shares  Dislikes  Likes  \
# 111         2022-01-17              37      43         8    267
# ...

# %%
df_agg.describe()
# Out:
#        Comments added       Shares    Dislikes         Likes  \
# count      223.000000   223.000000  223.000000    223.000000
# mean        63.654709   177.753363   17.497758   1008.865471
# std         91.559620   733.331174   69.578517   3577.895609
# min          0.000000     0.000000    0.000000      1.000000
# 25%         18.000000    19.000000    1.000000    163.000000
# 50%         37.000000    46.000000    4.000000    342.000000
# 75%         66.000000   112.500000   11.000000    713.000000
# max        907.000000  9583.000000  942.000000  46903.000000
#
#        Subscribers lost  Subscribers gained    RPM(USD)    CPM(USD)  \
# count        223.000000          223.000000  223.000000  221.000000
# mean          13.260090          587.309417    4.438300   11.440303
# std           33.242009         3302.316610    1.792295    3.342147
# min            0.000000            0.000000    0.000000    5.439000
# 25%            2.000000           27.000000    3.219500    9.377000
# ...

# %%
df_agg, df_agg_sub, df_comments, df_time = returndata()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 df_agg, df_agg_sub, df_comments, df_time = returndata()
#
# NameError: name 'returndata' is not defined

# %%
add_sidebar = st.sidebar.selectbox('Aggregate or Individual Video', ('Aggregate Metrics','Individual Video Analysis'))
# Out:
# 2024-08-28 03:12:14.024
# ...
#   command:
#
#     streamlit run C:\Users\91790\AppData\Local\Programs\Python\Python310\lib\site-packages\ipykernel_launcher.py [ARGUMENTS]

# %%
df_agg['Video publish time']
# Out:
# 1       May 8, 2020
# 2      Nov 12, 2020
# 3      Jul 16, 2020
# 4      Aug 29, 2020
# 5       Aug 5, 2020
#            ...
# 219    Nov 30, 2018
# 220    May 25, 2019
# 221    Dec 18, 2018
# 222     May 5, 2019
# 223     Jun 6, 2017
# Name: Video publish time, Length: 223, dtype: object

# %%
df_copy=df_agg.copy()

# %%
df_time=df_agg['Video publish time'].max()-pd.DateOffset(months =12)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 df_time=df_agg['Video publish time'].max()-pd.DateOffset(months =12)
#
# TypeError: unsupported operand type(s) for -: 'str' and 'DateOffset'

# %%
df_time
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 df_time
#
# NameError: name 'df_time' is not defined

# %%
df_agg['is_after_median'] = df_agg['Video publish time'] >= df_agg['Video publish time'].median()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\nanops.py:786, in nanmedian(values, axis, skipna, mask)
#     785 try:
# --> 786     values = values.astype("f8")
#     787 except ValueError as err:
#     788     # e.g. "could not convert string to float: 'a'"
#
# ValueError: could not convert string to float: 'May 8, 2020'
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 df_agg['is_after_median'] = df_agg['Video publish time'] >= df_agg['Video publish time'].median()
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\generic.py:11623, in NDFrame._add_numeric_operations.<locals>.median(self, axis, skipna, numeric_only, **kwargs)
# ...

# %%
df_agg
# Out:
#            Video                                        Video title  \
# 1    4OZip0cgOho  How I Would Learn Data Science (If I Had to St...
# 2    78LjdAAw0wA                  100K Channel Update + AMA Stream!
# 3    hO_YKK_0Qck  Uber Driver to Machine Learning Engineer in 9 ...
# 4    uXLnbdHMf8w          Why I'm Starting Data Science Over Again.
# 5    Xgg7dIKys9E  Interview with the Director of AI Research @ N...
# ..           ...                                                ...
# 219  FBgs-BSTIJE                    Demystifying Data Science Roles
# 220  Yr5T3T4tq-g  Most Data Science Hopefuls Overlook This Impor...
# 221  j-Z-je6K4Yg                   IT'S NOT TOO LATE TO LEARN CODE!
# 222  5jntoZX-Tc8  NASA Physicist Turned Data Scientist (Tim Bowl...
# 223  5p73cIRYCZg                     ProjectDemoCSC478_UFCFightData
#
#     Video publish time  Comments added  Shares  Dislikes  Likes  \
# 1          May 8, 2020             907    9583       942  46903
# ...

# %%
numeric_cols = np.array((df_copy.dtypes == 'float64') | (df_copy.dtypes == 'int64'))

# %%
numeric_cols
# Out:
# array([False, False, False,  True,  True,  True,  True,  True,  True,
#         True,  True,  True, False,  True,  True,  True,  True,  True,
#         True])

# %%
#metrics

# %%
if add_sidebar == 'Aggregate Metrics':
    st.write("Ken Jee YouTube Aggregated Data")
    
    df_agg_metrics = df_agg[['Video publish time','Views','Likes','Subscribers','Shares','Comments added','RPM(USD)','Average % viewed',
                             'Avg_duration_sec', 'Engagement_ratio','Subscribers gained']]
    metric_date_6mo = df_agg_metrics['Video publish time'].max() - pd.DateOffset(months =6)
    metric_date_12mo = df_agg_metrics['Video publish time'].max() - pd.DateOffset(months =12)
    metric_medians6mo = df_agg_metrics[df_agg_metrics['Video publish time'] >= metric_date_6mo].median()
    metric_medians12mo = df_agg_metrics[df_agg_metrics['Video publish time'] >= metric_date_12mo].median()
    metric_medians12mo = df_agg_metrics[df_agg_metrics['Video publish time'] >= metric_date_12mo].median()
    
    col1, col2, col3, col4, col5 = st.columns(5)
    columns = [col1, col2, col3, col4, col5]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[20], line 4
#       1 if add_sidebar == 'Aggregate Metrics':
#       2     st.write("Ken Jee YouTube Aggregated Data")
# ----> 4     df_agg_metrics = df_agg[['Video publish time','Views','Likes','Subscribers','Shares','Comments added','RPM(USD)','Average % viewed',
#       5                              'Avg_duration_sec', 'Engagement_ratio','Subscribers gained']]
#       6     metric_date_6mo = df_agg_metrics['Video publish time'].max() - pd.DateOffset(months =6)
#       7     metric_date_12mo = df_agg_metrics['Video publish time'].max() - pd.DateOffset(months =12)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py:3767, in DataFrame.__getitem__(self, key)
#    3765     if is_iterator(key):
#    3766         key = list(key)
# ...

# %%
    count = 0
    for i in metric_medians6mo.index:
        with columns[count]:
            delta = (metric_medians6mo[i] - metric_medians12mo[i])/metric_medians12mo[i]
            st.metric(label= i, value = round(metric_medians6mo[i],1), delta = "{:.2%}".format(delta))
            count += 1
            if count >= 5:
                count = 0
    #get date information / trim to relevant data 
    df_agg_diff['Publish_date'] = df_agg_diff['Video publish time'].apply(lambda x: x.date())
    df_agg_diff_final = df_agg_diff.loc[:,['Video title','Publish_date','Views','Likes','Subscribers','Shares','Comments added','RPM(USD)','Average % viewed',
                             'Avg_duration_sec', 'Engagement_ratio','Views / sub gained']]
    
    df_agg_numeric_lst = df_agg_diff_final.median().index.tolist()
    df_to_pct = {}
    for i in df_agg_numeric_lst:
        df_to_pct[i] = '{:.1%}'.format
    
    st.dataframe(df_agg_diff_final.style.hide().applymap(style_negative, props='color:red;').applymap(style_positive, props='color:green;').format(df_to_pct))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[22], line 2
#       1 count = 0
# ----> 2 for i in metric_medians6mo.index:
#       3     with columns[count]:
#       4         delta = (metric_medians6mo[i] - metric_medians12mo[i])/metric_medians12mo[i]
#
# NameError: name 'metric_medians6mo' is not defined
