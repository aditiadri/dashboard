# %%
import pandas as pd 
import numpy as np 
import plotly.graph_objects as go
import plotly.express as px
import streamlit as st
from datetime import datetime

# %%
    #def load_data():
    df_agg=pd.read_csv("Aggregated_Metrics_By_Video.csv").iloc[1:,:]
    df_agg_sub = pd.read_csv('Aggregated_Metrics_By_Country_And_Subscriber_Status.csv')
    df_comments = pd.read_csv('Aggregated_Metrics_By_Video.csv')
    df_time = pd.read_csv('Video_Performance_Over_Time.csv')
    df_agg.columns = ['Video','Video title','Video publish time','Comments added','Shares','Dislikes','Likes',
                      'Subscribers lost','Subscribers gained','RPM(USD)','CPM(USD)','Average % viewed','Average view duration',
                      'Views','Watch time (hours)','Subscribers','Your estimated revenue (USD)','Impressions','Impressions ctr(%)']
    df_agg['Video publish time'] = pd.to_datetime(df_agg['Video publish time'], format='%b %d, %Y')
    df_agg['Average view duration'] = df_agg['Average view duration'].apply(lambda x: datetime.strptime(x,'%H:%M:%S'))
    df_agg['Avg_duration_sec'] = df_agg['Average view duration'].apply(lambda x: x.second + x.minute*60 + x.hour*3600)
    df_agg['Engagement_ratio'] =  (df_agg['Comments added'] + df_agg['Shares'] +df_agg['Dislikes'] + df_agg['Likes']) /df_agg.Views
    df_agg['Views / sub gained'] = df_agg['Views'] / df_agg['Subscribers gained']
    df_agg.sort_values('Video publish time', ascending = False, inplace = True)
    df_time['Date'] = pd.to_datetime(df_time['Date'], format='%d %b %Y', errors='coerce')
    #return df_agg, df_agg_sub, df_comments, df_time

# %%
df_agg.columns
# Out:
# Index(['Video', 'Video title', 'Video publish time', 'Comments added',
#        'Shares', 'Dislikes', 'Likes', 'Subscribers lost', 'Subscribers gained',
#        'RPM(USD)', 'CPM(USD)', 'Average % viewed', 'Average view duration',
#        'Views', 'Watch time (hours)', 'Subscribers',
#        'Your estimated revenue (USD)', 'Impressions', 'Impressions ctr(%)',
#        'Avg_duration_sec', 'Engagement_ratio', 'Views / sub gained'],
#       dtype='object')

# %%
df_agg_sub.columns
# Out:
# Index(['Video Title', 'External Video ID', 'Video Length', 'Thumbnail link',
#        'Country Code', 'Is Subscribed', 'Views', 'Video Likes Added',
#        'Video Dislikes Added', 'Video Likes Removed',
#        'User Subscriptions Added', 'User Subscriptions Removed',
#        'Average View Percentage', 'Average Watch Time', 'User Comments Added'],
#       dtype='object')

# %%
df_time.columns
# Out:
# Index(['Date', 'Video Title', 'External Video ID', 'Video Length',
#        'Thumbnail link', 'Views', 'Video Likes Added', 'Video Dislikes Added',
#        'Video Likes Removed', 'User Subscriptions Added',
#        'User Subscriptions Removed', 'Average View Percentage',
#        'Average Watch Time', 'User Comments Added'],
#       dtype='object')

# %%
df_comments.columns
# Out:
# Index(['Video', 'Video title', 'Video pub­lish time', 'Com­ments ad­ded',
#        'Shares', 'Dis­likes', 'Likes', 'Sub­scribers lost',
#        'Sub­scribers gained', 'RPM (USD)', 'CPM (USD)',
#        'Av­er­age per­cent­age viewed (%)', 'Av­er­age view dur­a­tion',
#        'Views', 'Watch time (hours)', 'Sub­scribers',
#        'Your es­tim­ated rev­en­ue (USD)', 'Im­pres­sions',
#        'Im­pres­sions click-through rate (%)'],
#       dtype='object')

# %%
df_agg["revenue"]=(df_agg[ 'RPM(USD)']/1000* df_agg['Views'])

# %%
print(df_agg[['Video title', 'revenue']])
# Out:
#                                            Video title     revenue
# 111  Should You Be Excited About Web 3? (As a Data ...   17.773065
# 187  Should  @Luke Barousse Take This Data Analyst ...    4.518682
# 64          The Only Data Science Explanation You Need   61.363967
# 59   We Need to Talk About The LinkedIn Machine Lea...   62.830368
# 32   How I Would Learn Data Science in 2022 (If I H...  541.978588
# ..                                                 ...         ...
# 75           Should You Get A Masters in Data Science?  136.774224
# 190  How I Became A Data Scientist From a Business ...   24.370785
# 204  Predicting Season Long NBA Wins Using Multiple...   19.786029
# 138  Predicting Crypto-Currency Price Using RNN lST...   21.955908
# 223                     ProjectDemoCSC478_UFCFightData    0.003000
#
# [223 rows x 2 columns]

# %%
import seaborn as sns

# %%
df_agg
# Out:
#            Video                                        Video title  \
# 111  0jTtHYie3CU  Should You Be Excited About Web 3? (As a Data ...
# 187  2RWwN5ZT4tA  Should  @Luke Barousse Take This Data Analyst ...
# 64   rEWPqw6rMGI         The Only Data Science Explanation You Need
# 59   o-wsyxWbPOw  We Need to Talk About The LinkedIn Machine Lea...
# 32   xpIFS6jZbe8  How I Would Learn Data Science in 2022 (If I H...
# ..           ...                                                ...
# 75   RRSRKf9eQxc          Should You Get A Masters in Data Science?
# 190  IFceyuL6GZY  How I Became A Data Scientist From a Business ...
# 204  Y_SMU701qlA  Predicting Season Long NBA Wins Using Multiple...
# 138  qfRhKHV8-t4  Predicting Crypto-Currency Price Using RNN lST...
# 223  5p73cIRYCZg                     ProjectDemoCSC478_UFCFightData
#
#     Video publish time  Comments added  Shares  Dislikes  Likes  \
# 111         2022-01-17              37      43         8    267
# 187         2022-01-14              12       2         3     78
# 64          2022-01-10              62     141         5    722
# 59          2022-01-03              65      36        12    592
# 32          2021-12-27             109     767        53   4413
# ..                 ...             ...     ...       ...    ...
# 75          2018-11-14              56      41        10    276
# 190         2018-11-12              11      33         4    168
# 204         2018-07-10               7      45         2    159
# 138         2017-11-18              28     114        18    247
# 223         2017-06-06               0       2         0      1
#
#      Subscribers lost  Subscribers gained  RPM(USD)  ...  \
# 111                14                  18     4.055  ...
# 187                 1                   1     1.882  ...
# 64                 28                 136     5.971  ...
# 59                 10                  78     5.321  ...
# 32                 46                2553     6.836  ...
# ..                ...                 ...       ...  ...
# 75                  2                  81     7.398  ...
# 190                 0                  81     4.419  ...
# 204                 1                  34     2.883  ...
# 138                 1                 111     1.326  ...
# 223                 0                   0     0.050  ...
#
#      Average view duration  Views Watch time (hours)  Subscribers  \
# 111    1900-01-01 00:02:38   4383           192.5779            4
# 187    1900-01-01 00:00:38   2401            25.9375            0
# 64     1900-01-01 00:04:40  10277           801.5549          108
# 59     1900-01-01 00:02:46  11808           545.6332           68
# 32     1900-01-01 00:04:29  79283          5945.5420         2507
# ..                     ...    ...                ...          ...
# 75     1900-01-01 00:02:32  18488           782.5937           79
# 190    1900-01-01 00:03:57   5515           363.4858           81
# 204    1900-01-01 00:02:25   6863           276.7257           33
# 138    1900-01-01 00:01:45  16558           487.2194          110
# 223    1900-01-01 00:01:04     60             1.0684            0
#
#      Your estimated revenue (USD)  Impressions  Impressions ctr(%)  \
# 111                        16.549        65130                2.95
# 187                         1.720        25094                2.64
# 64                         60.498       215491                2.22
# 59                         62.568       166915                3.32
# 32                        528.286      1420968                3.31
# ..                            ...          ...                 ...
# 75                        136.708       173610                8.40
# 190                        24.358        58816                5.72
# 204                        19.772        53865                4.03
# 138                        21.944       168508                5.65
# 223                         0.003          365               11.51
#
#      Avg_duration_sec  Engagement_ratio  Views / sub gained
# 111               158          0.080995          243.500000
# 187                38          0.039567         2401.000000
# 64                280          0.090493           75.566176
# 59                166          0.059705          151.384615
# 32                269          0.067379           31.054837
# ..                ...               ...                 ...
# 75                152          0.020716          228.246914
# 190               237          0.039166           68.086420
# 204               145          0.031036          201.852941
# 138               105          0.024580          149.171171
# 223                64          0.050000                 inf
#
# [223 rows x 22 columns]

# %%
df_agg, df_agg_sub, df_comments, df_time = load_data()

# %%
df_agg_diff = df_agg.copy()
df_agg_diff['Video publish time'] = pd.to_datetime(df_agg_diff['Video publish time'])

metric_date_12mo = df_agg_diff['Video publish time'].max() - pd.DateOffset(months =12)

# %%
metric_date_12mo
# Out:
# Timestamp('2021-01-17 00:00:00')

# %%
df_agg_diff['Video publish time']
# Out:
# 111   2022-01-17
# 187   2022-01-14
# 64    2022-01-10
# 59    2022-01-03
# 32    2021-12-27
#          ...
# 75    2018-11-14
# 190   2018-11-12
# 204   2018-07-10
# 138   2017-11-18
# 223   2017-06-06
# Name: Video publish time, Length: 223, dtype: datetime64[ns]

# %%
df_agg_diff
# Out:
#            Video                                        Video title  \
# 111  0jTtHYie3CU  Should You Be Excited About Web 3? (As a Data ...
# 187  2RWwN5ZT4tA  Should  @Luke Barousse Take This Data Analyst ...
# 64   rEWPqw6rMGI         The Only Data Science Explanation You Need
# 59   o-wsyxWbPOw  We Need to Talk About The LinkedIn Machine Lea...
# 32   xpIFS6jZbe8  How I Would Learn Data Science in 2022 (If I H...
# ..           ...                                                ...
# 75   RRSRKf9eQxc          Should You Get A Masters in Data Science?
# 190  IFceyuL6GZY  How I Became A Data Scientist From a Business ...
# 204  Y_SMU701qlA  Predicting Season Long NBA Wins Using Multiple...
# 138  qfRhKHV8-t4  Predicting Crypto-Currency Price Using RNN lST...
# 223  5p73cIRYCZg                     ProjectDemoCSC478_UFCFightData
#
#     Video publish time  Comments added  Shares  Dislikes  Likes  \
# 111         2022-01-17              37      43         8    267
# 187         2022-01-14              12       2         3     78
# 64          2022-01-10              62     141         5    722
# 59          2022-01-03              65      36        12    592
# 32          2021-12-27             109     767        53   4413
# ..                 ...             ...     ...       ...    ...
# 75          2018-11-14              56      41        10    276
# 190         2018-11-12              11      33         4    168
# 204         2018-07-10               7      45         2    159
# 138         2017-11-18              28     114        18    247
# 223         2017-06-06               0       2         0      1
#
#      Subscribers lost  Subscribers gained  RPM(USD)  ...  \
# 111                14                  18     4.055  ...
# 187                 1                   1     1.882  ...
# 64                 28                 136     5.971  ...
# 59                 10                  78     5.321  ...
# 32                 46                2553     6.836  ...
# ..                ...                 ...       ...  ...
# 75                  2                  81     7.398  ...
# 190                 0                  81     4.419  ...
# 204                 1                  34     2.883  ...
# 138                 1                 111     1.326  ...
# 223                 0                   0     0.050  ...
#
#      Average view duration  Views Watch time (hours)  Subscribers  \
# 111    1900-01-01 00:02:38   4383           192.5779            4
# 187    1900-01-01 00:00:38   2401            25.9375            0
# 64     1900-01-01 00:04:40  10277           801.5549          108
# 59     1900-01-01 00:02:46  11808           545.6332           68
# 32     1900-01-01 00:04:29  79283          5945.5420         2507
# ..                     ...    ...                ...          ...
# 75     1900-01-01 00:02:32  18488           782.5937           79
# 190    1900-01-01 00:03:57   5515           363.4858           81
# 204    1900-01-01 00:02:25   6863           276.7257           33
# 138    1900-01-01 00:01:45  16558           487.2194          110
# 223    1900-01-01 00:01:04     60             1.0684            0
#
#      Your estimated revenue (USD)  Impressions  Impressions ctr(%)  \
# 111                        16.549        65130                2.95
# 187                         1.720        25094                2.64
# 64                         60.498       215491                2.22
# 59                         62.568       166915                3.32
# 32                        528.286      1420968                3.31
# ..                            ...          ...                 ...
# 75                        136.708       173610                8.40
# 190                        24.358        58816                5.72
# 204                        19.772        53865                4.03
# 138                        21.944       168508                5.65
# 223                         0.003          365               11.51
#
#      Avg_duration_sec  Engagement_ratio  Views / sub gained
# 111               158          0.080995          243.500000
# 187                38          0.039567         2401.000000
# 64                280          0.090493           75.566176
# 59                166          0.059705          151.384615
# 32                269          0.067379           31.054837
# ..                ...               ...                 ...
# 75                152          0.020716          228.246914
# 190               237          0.039166           68.086420
# 204               145          0.031036          201.852941
# 138               105          0.024580          149.171171
# 223                64          0.050000                 inf
#
# [223 rows x 22 columns]

# %%
median_agg =  df_agg_diff[df_agg_diff['Video publish time'] >= metric_date_12mo]

# %%
median_agg
# Out:
#             Video                                        Video title  \
# 111   0jTtHYie3CU  Should You Be Excited About Web 3? (As a Data ...
# 187   2RWwN5ZT4tA  Should  @Luke Barousse Take This Data Analyst ...
# 64    rEWPqw6rMGI         The Only Data Science Explanation You Need
# 59    o-wsyxWbPOw  We Need to Talk About The LinkedIn Machine Lea...
# 32    xpIFS6jZbe8  How I Would Learn Data Science in 2022 (If I H...
# 132   -zbLpoJVBMI     What the Heck is WSL 2? (My New Favorite Tool)
# 191   scSc6YSanQ0  How Statistics Saved the US SERIOUS $$$$ Durin...
# 62    FqNpDNmpcEo  How Zillow Lost $500 MILLION With Machine Lear...
# 61    vwvdtXMcNzI          Why Is Data Engineering So HOT Right Now?
# 24    2qVWurPFwfc                             Is Data Science Dying?
# 73    35g8fCi-kbw  7 Incredible Books That Transformed My Health ...
# 147   n6MiRgxN5iA  Why EVERYONE Should Start a Podcast (Including...
# 157   ammCGdzSoag  Building a Burrito Dashboard - Data Science Pr...
# 118   15c7WD-lKUY                         ML Ops: What is it REALLY?
# 133   TjGFBQC27ng  Business Skills for Data Science: What are the...
# 217   qUK5Vk4NvBw  #66DaysOfData Round 3 Live Event! (feat. @Stat...
# 114   cnqTU6eJwH0      The TRUTH About My First Data Science Project
# 77    k8YxyrcAXJs  Is Data Visualization Important for Data Scien...
# 170   VvnOXDCVm8k  Project Presentation - Expectations vs. Realit...
# 171   68GGPK3WaqI  Data Science Project - Expectations vs Reality...
# 50    S4Lei5mOppc                            How I Learned to Learn.
# 166   tG_UW_p0UqE          Is Spotify Shuffle Really Random? #Shorts
# 182   143WWA5Sy9k  I Eat a Papaya Live on Stream (Plus Q&A for 15...
# 115   s1gD35Z4eUc           Why are APIs Important for Data Science?
# 92    nrEJGGxcoTc             Is Your Phone REALLY Listening to You?
# 88    KfpOuSH9gDc  Kaggle vs Github - Which is Best for Your Data...
# 172   sICJ6a2wX5g                #66DaysOfData - 3 Reasons to Start!
# 146   iiSZqsQKNX8                #66DaysOfData - What is it? #shorts
# 116   IoUWD1h6xUs          A Quick Data Science Project Tip! #SHORTS
# 46    7JCterBrcvk  Discouraged with Data Science? - Watch THIS vi...
# 66    KU__lDJj5iU                  How Data Science Projects Pay Off
# 55    8nTmuKI2oyA  How I Use Data to Optimize My Life | What I Co...
# 150   SaWxVk7rDp4        What is a lambda function (python)? #shorts
# 95    n7kjelw9s2w  Why Kaggle Should Be Your Favorite Data Scienc...
# 108   8Pi36Nj6P9A      What is Pandas? (Data & Data Science) #shorts
# 31    hOUrxTeBJQc      The 7 Biggest Data Science  Beginner Mistakes
# 97    -ONQ628CXKQ  Data Scientist Reacts: REAL Data Science Job A...
# 15    sHRq-LshG3U     Why You Probably Won't Become a Data Scientist
# 48    EMq4PH7PCeA      How to Go From Data Analyst to Data Scientist
# 102   BlSrorP32WM  Why I Have 2 Offices for Data Science & Conten...
# 86    pPfw2fzwNiM  MARCH MADNESS - Will My Machine Learning Model...
# 78    hcHSSyHbgMQ               My Regrets as a Data Science Student
# 94    ITAxTid_1YU     My Daily Battle With Time - Will I Win? [Vlog]
# 117   fU3DOXjwufg  What is the Future of my Comment Leaderboard P...
# 126   tJI-1mHeXoA  How to Build a Website  - Building my ULTIMATE...
# 20    SVtRsDhHlDk                            Why I Quit Data Science
# 74    OtqQYqRNDGI  🌶 Hot Topics in Tech: Data Science Explained #...
# 65    uic34RTaI-w  How I Balance Data Science and Content Creatio...
#
#     Video publish time  Comments added  Shares  Dislikes  Likes  \
# 111         2022-01-17              37      43         8    267
# 187         2022-01-14              12       2         3     78
# 64          2022-01-10              62     141         5    722
# 59          2022-01-03              65      36        12    592
# 32          2021-12-27             109     767        53   4413
# 132         2021-12-17              29      39         6    237
# 191         2021-12-10              10      20         5    212
# 62          2021-12-03              62     309         4    869
# 61          2021-11-26              63     174         9    786
# 24          2021-11-19             148     408        56   2378
# 73          2021-11-12              56      60         1    343
# 147         2021-11-05              25      34         1    189
# 157         2021-10-29              22      49         2    191
# 118         2021-10-22              35      19         1    219
# 133         2021-10-18              29      34         4    228
# 217         2021-10-12               4      16         0    133
# 114         2021-10-08              37      22         1    228
# 77          2021-08-20              54      53         2    481
# 170         2021-08-07              17      16         5    230
# 171         2021-08-06              16      20        10    484
# 50          2021-07-31              71     210        12   1455
# 166         2021-07-21              19      55         2    385
# 182         2021-07-16              13       8         6     93
# 115         2021-07-09              37      38         2    351
# 92          2021-07-03              46      69         6    273
# 88          2021-06-25              47      42        11    416
# 172         2021-06-18              16       8         5    184
# 146         2021-06-11              26      30         4    297
# 116         2021-06-03              36      60         5    712
# 46          2021-05-28              76      58         1    388
# 66          2021-05-22              60      49         3    565
# 55          2021-05-14              67      77         6    457
# 150         2021-05-13              24      22        16    540
# 95          2021-05-07              44      46        12    640
# 108         2021-04-30              38      25        12    489
# 31          2021-04-23             117     181        13   2252
# 97          2021-04-16              43      89         9    576
# 15          2021-04-09             213     386       129   3225
# 48          2021-04-02              73     159         3   1176
# 102         2021-03-26              41      24         1    134
# 86          2021-03-19              48      41         2    260
# 78          2021-03-12              53      85         9    749
# 94          2021-03-08              45       6         2    193
# 117         2021-02-26              36       8         1    197
# 126         2021-02-19              32      28        13    157
# 20          2021-02-12             165     197       159   2274
# 74          2021-01-29              56      25        26    380
# 65          2021-01-23              62      49         0    284
#
#      Subscribers lost  Subscribers gained  RPM(USD)  ...  \
# 111                14                  18     4.055  ...
# 187                 1                   1     1.882  ...
# 64                 28                 136     5.971  ...
# 59                 10                  78     5.321  ...
# 32                 46                2553     6.836  ...
# 132                20                  27     3.611  ...
# 191                 0                   2     1.947  ...
# 62                 16                 142     7.098  ...
# 61                 16                 278     4.452  ...
# 24                 34                 981     5.272  ...
# 73                 17                  40     3.942  ...
# 147                11                  15     4.247  ...
# 157                 9                  45     5.525  ...
# 118                 8                  21     5.943  ...
# 133                10                  31     6.367  ...
# 217                12                  22     3.078  ...
# 114                21                  33     4.338  ...
# 77                 37                  84     4.843  ...
# 170                 8                   6     2.059  ...
# 171                 2                  38     3.190  ...
# 50                 23                 336     7.008  ...
# 166                 5                  25     1.698  ...
# 182                33                  12     2.611  ...
# 115                 7                  76     5.662  ...
# 92                 15                  16     4.367  ...
# 88                 13                  47     4.395  ...
# 172                 2                   6     1.699  ...
# 146                 2                  43     2.968  ...
# 116                 3                  68     1.608  ...
# 46                 24                  60     7.307  ...
# 66                 19                 150     4.805  ...
# 55                  9                  66     6.795  ...
# 150                 5                  72     2.097  ...
# 95                  9                  96     1.807  ...
# 108                 7                  64     1.378  ...
# 31                 23                1053     7.726  ...
# 97                 14                 366     4.803  ...
# 15                 67                2237     5.569  ...
# 48                 24                 613     4.373  ...
# 102                11                  18     5.721  ...
# 86                  6                 281     5.501  ...
# 78                 15                 172     6.264  ...
# 94                 10                  12     3.217  ...
# 117                10                 102     2.945  ...
# 126                13                  21     8.647  ...
# 20                 85                 832     4.042  ...
# 74                 18                  53     2.698  ...
# 65                 17                  49     3.257  ...
#
#      Average view duration   Views Watch time (hours)  Subscribers  \
# 111    1900-01-01 00:02:38    4383           192.5779            4
# 187    1900-01-01 00:00:38    2401            25.9375            0
# 64     1900-01-01 00:04:40   10277           801.5549          108
# 59     1900-01-01 00:02:46   11808           545.6332           68
# 32     1900-01-01 00:04:29   79283          5945.5420         2507
# 132    1900-01-01 00:02:25    5004           202.1937            7
# 191    1900-01-01 00:00:43    3130            37.4755            2
# 62     1900-01-01 00:05:06   16933          1440.0058          126
# 61     1900-01-01 00:03:04   17268           883.2341          262
# 24     1900-01-01 00:03:12   70043          3736.8190          947
# 73     1900-01-01 00:03:34    6192           368.9579           23
# 147    1900-01-01 00:02:37    3092           134.9815            4
# 157    1900-01-01 00:03:45    5883           368.4759           36
# 118    1900-01-01 00:02:41    4252           190.2194           13
# 133    1900-01-01 00:03:52    4413           285.1689           21
# 217    1900-01-01 00:04:52    2038           165.5004           10
# 114    1900-01-01 00:04:05    3966           270.7990           12
# 77     1900-01-01 00:02:14   10403           389.9063           47
# 170    1900-01-01 00:00:45    5932            74.4665           -2
# 171    1900-01-01 00:00:43   14136           169.5390           36
# 50     1900-01-01 00:05:17   23506          2074.7039          313
# 166    1900-01-01 00:00:41    6579            76.0888           20
# 182    1900-01-01 00:04:21    2271           165.2476          -21
# 115    1900-01-01 00:02:50    6540           309.6966           69
# 92     1900-01-01 00:02:31    4569           192.1812            1
# 88     1900-01-01 00:02:43    8832           402.3071           34
# 172    1900-01-01 00:00:30    3443            28.8076            4
# 146    1900-01-01 00:00:32    6101            54.2392           41
# 116    1900-01-01 00:00:34   12328           118.3273           65
# 46     1900-01-01 00:03:38    6825           414.0030           36
# 66     1900-01-01 00:02:46    9342           431.1819          131
# 55     1900-01-01 00:03:15    9135           495.6710           57
# 150    1900-01-01 00:00:37    8275            85.6748           67
# 95     1900-01-01 00:00:31   14780           128.0017           87
# 108    1900-01-01 00:00:25   12931            90.3324           57
# 31     1900-01-01 00:03:49   48261          3082.4798         1030
# 97     1900-01-01 00:03:25   20158          1151.5371          352
# 15     1900-01-01 00:03:34  108133          6435.5906         2170
# 48     1900-01-01 00:02:15   40202          1509.9240          589
# 102    1900-01-01 00:02:59    3543           176.9124            7
# 86     1900-01-01 00:02:22    9370           369.7456          275
# 78     1900-01-01 00:02:55   20150           983.9832          157
# 94     1900-01-01 00:02:51    3615           172.3023            2
# 117    1900-01-01 00:01:43    4912           141.5038           92
# 126    1900-01-01 00:03:00    5483           274.8013            8
# 20     1900-01-01 00:02:16   98777          3756.0683          747
# 74     1900-01-01 00:00:35    8009            79.7725           35
# 65     1900-01-01 00:02:50    6776           320.0906           32
#
#      Your estimated revenue (USD)  Impressions  Impressions ctr(%)  \
# 111                        16.549        65130                2.95
# 187                         1.720        25094                2.64
# 64                         60.498       215491                2.22
# 59                         62.568       166915                3.32
# 32                        528.286      1420968                3.31
# 132                        18.005       132645                1.81
# 191                         2.484        59027                1.61
# 62                        119.891       312137                2.63
# 61                         76.731       299897                2.94
# 24                        368.530      1071989                3.78
# 73                         24.375       126506                2.29
# 147                        13.118       116219                1.28
# 157                        32.398       137560                2.38
# 118                        25.224       121572                1.83
# 133                        28.034       114051                2.01
# 217                         6.269       138024                0.64
# 114                        17.075        87610                2.51
# 77                         50.319       322856                1.95
# 170                         6.170       133476                1.69
# 171                        12.271       166268                3.82
# 50                        163.843       448761                2.48
# 166                         5.974       141902                1.87
# 182                         5.929       154655                0.80
# 115                        37.014       164540                2.51
# 92                         19.933       136065                1.95
# 88                         38.723       178720                2.89
# 172                         2.917        63656                1.90
# 146                        12.009        97878                2.70
# 116                        12.688       154198                2.73
# 46                         49.835       180455                2.32
# 66                         44.874       175035                3.33
# 55                         62.009       167823                3.02
# 150                         6.943       155550                2.15
# 95                         13.458       242413                2.50
# 108                         7.744       190532                1.97
# 31                        372.245       676516                3.45
# 97                         96.734       195209                2.86
# 15                        601.671      1302907                5.04
# 48                        175.663       325998                4.90
# 102                        20.258       124125                1.57
# 86                         51.333       154187                1.74
# 78                        126.139       216390                3.97
# 94                         11.628       115355                1.72
# 117                        14.455       130104                1.02
# 126                        47.386       105754                2.95
# 20                        399.180       659163                8.62
# 74                         10.292       178890                1.64
# 65                         22.063       154264                1.17
#
#      Avg_duration_sec  Engagement_ratio  Views / sub gained
# 111               158          0.080995          243.500000
# 187                38          0.039567         2401.000000
# 64                280          0.090493           75.566176
# 59                166          0.059705          151.384615
# 32                269          0.067379           31.054837
# 132               145          0.062150          185.333333
# 191                43          0.078914         1565.000000
# 62                306          0.073466          119.246479
# 61                184          0.059764           62.115108
# 24                192          0.042688           71.399592
# 73                214          0.074289          154.800000
# 147               157          0.080530          206.133333
# 157               225          0.044875          130.733333
# 118               161          0.064440          202.476190
# 133               232          0.066848          142.354839
# 217               292          0.075074           92.636364
# 114               245          0.072617          120.181818
# 77                134          0.056714          123.845238
# 170                45          0.045179          988.666667
# 171                43          0.037493          372.000000
# 50                317          0.074364           69.958333
# 166                41          0.070071          263.160000
# 182               261          0.052840          189.250000
# 115               170          0.065443           86.052632
# 92                151          0.086233          285.562500
# 88                163          0.058424          187.914894
# 172                30          0.061865          573.833333
# 146                32          0.058515          141.883721
# 116                34          0.065947          181.294118
# 46                218          0.076630          113.750000
# 66                166          0.072468           62.280000
# 55                195          0.066448          138.409091
# 150                37          0.072749          114.930556
# 95                 31          0.050203          153.958333
# 108                25          0.043616          202.046875
# 31                229          0.053107           45.831909
# 97                205          0.035569           55.076503
# 15                214          0.036557           48.338400
# 48                135          0.035098           65.582382
# 102               179          0.056449          196.833333
# 86                142          0.037460           33.345196
# 78                175          0.044467          117.151163
# 94                171          0.068050          301.250000
# 117               103          0.049267           48.156863
# 126               180          0.041948          261.095238
# 20                136          0.028296          118.722356
# 74                 35          0.060807          151.113208
# 65                170          0.058294          138.285714
#
# [48 rows x 22 columns]

# %%
numeric_cols = np.array((df_agg_diff.dtypes == 'float64') | (df_agg_diff.dtypes == 'int64'))

# %%
numeric_cols
# Out:
# array([False, False, False,  True,  True,  True,  True,  True,  True,
#         True,  True,  True, False,  True,  True,  True,  True,  True,
#         True,  True,  True,  True])

# %%
numeric_cols = df_agg_diff.select_dtypes(include=[np.float64, np.int64]).columns

# Filter median_agg to keep only the numeric values corresponding to numeric_cols
numeric_median_agg = median_agg[numeric_cols]

# Apply the arithmetic operation only to the numeric columns
df_agg_diff[numeric_cols] = (df_agg_diff[numeric_cols] - numeric_median_agg).div(numeric_median_agg)

# %%
df_time_diff = pd.merge(df_time, df_agg.loc[:,['Video','Video publish time']], left_on ='External Video ID', right_on = 'Video')
df_time_diff['days_published'] = (df_time_diff['Date'] - df_time_diff['Video publish time']).dt.days

# get last 12 months of data rather than all data 
date_12mo = df_agg['Video publish time'].max() - pd.DateOffset(months =12)
df_time_diff_yr = df_time_diff[df_time_diff['Video publish time'] >= date_12mo]

# %%
add_sidebar=st.sidebar.selectbox('Aggregate or Individual Video', ('Aggregate Metrics','Individual Video Analysis'))
# Out:
# 2024-09-03 15:39:55.626 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-03 15:39:55.628 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-03 15:39:55.634 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-03 15:39:55.636 WARNING streamlit.runtime.state.session_state_proxy: Session state does not function when running a script without `streamlit run`
# 2024-09-03 15:39:55.637 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-03 15:39:56.047
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run C:\Users\91790\AppData\Local\Programs\Python\Python310\lib\site-packages\ipykernel_launcher.py [ARGUMENTS]
# 2024-09-03 15:39:56.049 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %%
if add_sidebar == 'Aggregate Metrics':
    st.write("Agg")
    df_agg_metrics = df_agg[['Video publish time','Views','Likes','Subscribers','Shares','Comments added','RPM(USD)','Average % viewed',
                             'Avg_duration_sec', 'Engagement_ratio','Views / sub gained']]
    metric_date_6mo = df_agg_metrics['Video publish time'].max() - pd.DateOffset(months =6)
    metric_date_12mo = df_agg_metrics['Video publish time'].max() - pd.DateOffset(months =12)
    metric_medians6mo = df_agg_metrics[df_agg_metrics['Video publish time'] >= metric_date_6mo].median()
    metric_medians12mo = df_agg_metrics[df_agg_metrics['Video publish time'] >= metric_date_12mo].median()
# Out:
# 2024-09-03 16:29:19.377 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-03 16:29:19.379 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-03 16:29:19.379 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-03 16:29:19.380 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %%
col1,col2,col3,col4,col5=st.columns(5)
# Out:
# 2024-09-03 15:40:03.966 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-03 15:40:03.969 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-03 15:40:03.971 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-03 15:40:03.973 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-03 15:40:03.974 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-03 15:40:03.977 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %%
columns=[col1,col2,col3,col4,col5]

# %%
    count = 0
    for i in metric_medians6mo.index:
        if i=='Video publish time':
            continue 
        
        with columns[count]:
            delta = (metric_medians6mo[i] - metric_medians12mo[i])/metric_medians12mo[i]
            st.metric(label= i, value = round(metric_medians6mo[i],1), delta = "{:.2%}".format(delta))
            count += 1
            if count >= 5:
                count = 0
# Out:
# 2024-09-03 15:40:08.681 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-03 15:40:08.683 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-03 15:40:08.685 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-03 15:40:08.687 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-03 15:40:08.688 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-03 15:40:08.691 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-03 15:40:08.693 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-03 15:40:08.696 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-03 15:40:08.698 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-03 15:40:08.699 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-03 15:40:08.701 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-03 15:40:08.703 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-03 15:40:08.704 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-03 15:40:08.706 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-03 15:40:08.709 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-03 15:40:08.711 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-03 15:40:08.714 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-03 15:40:08.716 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-03 15:40:08.718 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-03 15:40:08.720 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %%
metric_medians6mo
# Out:
# Video publish time    2021-11-08 12:00:00
# Views                              6062.0
# Likes                               305.0
# Subscribers                          22.0
# Shares                               41.0
# Comments added                       36.0
# RPM(USD)                            4.395
# Average % viewed                   41.225
# Avg_duration_sec                    175.0
# Engagement_ratio                 0.067113
# Views / sub gained             146.869727
# dtype: object

# %%
metric_medians12mo
# Out:
# Video publish time    2021-07-06 00:00:00
# Views                              7417.0
# Likes                               382.5
# Subscribers                          38.5
# Shares                               42.5
# Comments added                       43.5
# RPM(USD)                             4.37
# Average % viewed                   41.175
# Avg_duration_sec                    166.0
# Engagement_ratio                 0.060285
# Views / sub gained             140.146406
# dtype: object

# %%
    df_agg_diff['Publish_date'] = df_agg_diff['Video publish time'].apply(lambda x: x.date())
    df_agg_diff_final = df_agg_diff.loc[:,['Video title','Publish_date','Views','Likes','Subscribers','Shares','Comments added','RPM(USD)','Average % viewed',
                             'Avg_duration_sec', 'Engagement_ratio','Views / sub gained']]

# %%
st.dataframe(df_agg_diff_final)
# Out:
# 2024-09-03 15:40:16.981 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-03 15:40:16.983 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# DeltaGenerator()

# %%
# Select only numeric columns from the DataFrame
numeric_cols = df_agg_diff_final.select_dtypes(include=[np.number])

# Apply the median function only to numeric columns
df_agg_numeric_lst = numeric_cols.median().index.tolist()

# Now df_agg_numeric_lst will contain the names of numeric columns where median was successfully calculated

# %%
def style_negative(v, props=''):
    """ Style negative values in dataframe"""
    try: 
        return props if v < 0 else None
    except:
        pass

# %%
def style_negative(v, props=''):
    """ Style negative values in dataframe"""
    try: 
        return props if v < 0 else None
    except:
        pass

# %%
def style_positive(v, props=''):
    """Style positive values in dataframe"""
    try: 
        return props if v > 0 else None
    except:
        pass

# %%
def audience_simple(country):
    """Show top represented countries"""
    if country == 'US':
        return 'USA'
    elif country == 'IN':
        return 'India'
    else:
        return 'Other'

# %%
    st.dataframe(df_agg_diff_final.style.hide().applymap(style_negative, props='color:red;').applymap(style_positive, props='color:green;').format(df_to_pct))
# Out:
# 2024-09-03 16:25:11.496 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-03 16:25:11.538 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-03 16:25:11.539 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# DeltaGenerator()

# %%
df_to_pct = {}
for i in df_agg_numeric_lst:
    
    df_to_pct[i] = '{:.1%}'.format

# %%
#individual metrics

# %%
if add_sidebar == 'Individual Video Analysis':
    videos = tuple(df_agg['Video title'])
    st.write("Individual Video Performance")
    video_select = st.selectbox('Pick a Video:', videos)
    agg_filtered = df_agg[df_agg['Video title'] == video_select]
    agg_sub_filtered = df_agg_sub[df_agg_sub['Video Title'] == video_select]
    agg_sub_filtered['Country'] = agg_sub_filtered['Country Code'].apply(audience_simple)
    agg_sub_filtered.sort_values('Is Subscribed', inplace= True)   
    fig = px.bar(agg_sub_filtered, x ='Views', y='Is Subscribed', color ='Country', orientation ='h')
    st.plotly_chart(fig)
    agg_time_filtered = df_time_diff[df_time_diff['Video Title'] == video_select]
    first_30 = agg_time_filtered[agg_time_filtered['days_published'].between(0,30)]
    first_30 = first_30.sort_values('days_published')

# %%
    fig2 = go.Figure()
    fig2.add_trace(go.Scatter(x=views_cumulative['days_published'], y=views_cumulative['20pct_views'],
                    mode='lines',
                    name='20th percentile', line=dict(color='purple', dash ='dash')))
    fig2.add_trace(go.Scatter(x=views_cumulative['days_published'], y=views_cumulative['median_views'],
                        mode='lines',
                        name='50th percentile', line=dict(color='black', dash ='dash')))
    fig2.add_trace(go.Scatter(x=views_cumulative['days_published'], y=views_cumulative['80pct_views'],
                        mode='lines', 
                        name='80th percentile', line=dict(color='royalblue', dash ='dash')))
    fig2.add_trace(go.Scatter(x=first_30['days_published'], y=first_30['Views'].cumsum(),
                        mode='lines', 
                        name='Current Video' ,line=dict(color='firebrick',width=8)))
        
    fig2.update_layout(title='View comparison first 30 days',
                   xaxis_title='Days Since Published',
                   yaxis_title='Cumulative views')
    
    st.plotly_chart(fig2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[71], line 11
#       5 fig2.add_trace(go.Scatter(x=views_cumulative['days_published'], y=views_cumulative['median_views'],
#       6                     mode='lines',
#       7                     name='50th percentile', line=dict(color='black', dash ='dash')))
#       8 fig2.add_trace(go.Scatter(x=views_cumulative['days_published'], y=views_cumulative['80pct_views'],
#       9                     mode='lines',
#      10                     name='80th percentile', line=dict(color='royalblue', dash ='dash')))
# ---> 11 fig2.add_trace(go.Scatter(x=first_30['days_published'], y=first_30['Views'].cumsum(),
#      12                     mode='lines',
#      13                     name='Current Video' ,line=dict(color='firebrick',width=8)))
#      15 fig2.update_layout(title='View comparison first 30 days',
#      16                xaxis_title='Days Since Published',
#      17                yaxis_title='Cumulative views')
#      19 st.plotly_chart(fig2)
#
# NameError: name 'first_30' is not defined

# %%
views_days = pd.pivot_table(df_time_diff_yr,index= 'days_published',values ='Views', aggfunc = [np.mean,np.median,lambda x: np.percentile(x, 80),lambda x: np.percentile(x, 20)]).reset_index()
views_days.columns = ['days_published','mean_views','median_views','80pct_views','20pct_views']
views_days = views_days[views_days['days_published'].between(0,30)]
views_cumulative = views_days.loc[:,['days_published','median_views','80pct_views','20pct_views']] 
views_cumulative.loc[:,['median_views','80pct_views','20pct_views']] = views_cumulative.loc[:,['median_views','80pct_views','20pct_views']].cumsum()

# %%
    agg_time_filtered = df_time_diff[df_time_diff['Video Title'] == video_select]
    first_30 = agg_time_filtered[agg_time_filtered['days_published'].between(0,30)]
    first_30 = first_30.sort_values('days_published')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[72], line 1
# ----> 1 agg_time_filtered = df_time_diff[df_time_diff['Video Title'] == video_select]
#       2 first_30 = agg_time_filtered[agg_time_filtered['days_published'].between(0,30)]
#       3 first_30 = first_30.sort_values('days_published')
#
# NameError: name 'video_select' is not defined
